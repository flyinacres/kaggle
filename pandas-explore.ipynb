# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])

# %%
s
# Out:
# a   -0.445968
# b    0.177475
# c    1.386102
# d   -0.666114
# e    0.777195
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {"b": 1, "a": 0, "c": 2}

# %%
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64
