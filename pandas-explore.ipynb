# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series(data, index=index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/3475463259.py in <cell line: 0>()
# ----> 1 s = pd.Series(data, index=index)
#
# NameError: name 'data' is not defined
